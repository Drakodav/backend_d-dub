# %%
import vaex

dir = '../output/'

# %%
vaex.open(dir+'gtfsr_processed.hdf5')
# Out:
# #          route_id      start_date    start_time    stop_sequence    departure    arrival    stop_id       timestamp            direction    arrival_time    departure_time    shape_dist_traveled    lat               lon                direction_angle     shape_dist_between    trip_id                        p_avg_vol
# 0          17-126-cm1-1  20210109      18:05:00      35               60           60         8260B1039501  2021-01-09 19:33:08  0            19:28:00        19:28:00          45525.95               53.1693862708668  -6.80924232784757  -106.3378492208107  639.1299999999974     797.7.17-126-cm1-1.71.O        93.88495735930503
# 1          17-126-cm1-1  20210109      18:10:00      1                0            0          8260B104001   2021-01-09 19:33:08  1            18:10:00        18:10:00          0.0                    53.1568549945854  -6.91038476630496  73.71167359745287   0.0                   841.7.17-126-cm1-1.72.I        106.57334821707353
# ...
